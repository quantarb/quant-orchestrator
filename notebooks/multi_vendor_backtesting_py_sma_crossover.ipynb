# %% [markdown]
# # Multi Vendor Backtesting.py SMA Crossover
#
# This notebook calls the quant-orchestrator job that compares fmp and yfinance using a fixed backtesting.py SMA crossover.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
if not (repo_root / 'quant_orchestrator').exists():
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from quant_orchestrator.backtests.research import run_multi_vendor_backtesting_py_sma_comparison


result = run_multi_vendor_backtesting_py_sma_comparison(
    providers=('fmp', 'yfinance'),
    start='2020-01-01',
    end=None,
    fast_window=50,
    slow_window=200,
    capital_base=100_000.0,
)
symbol_report, portfolio_report, runs_by_provider = result

print('Symbol-level report:')
display(symbol_report.loc[:, ['provider', 'symbol', 'start', 'end', 'bars', 'trades', 'final_equity', 'total_return', 'max_drawdown', 'elapsed_seconds']].round(4).head(10))
print()
print('Portfolio report:')
display(portfolio_report.loc[:, ['provider', 'symbol', 'bars', 'trades', 'final_equity', 'total_return', 'max_drawdown', 'elapsed_seconds']].round(4).head(10))
print()
comparison = portfolio_report.loc[:, ['provider', 'total_return', 'max_drawdown', 'daily_vol', 'elapsed_seconds']].set_index('provider')
comparison['return_diff_vs_fmp'] = comparison['total_return'] - float(comparison.loc['fmp', 'total_return'])
comparison['drawdown_diff_vs_fmp'] = comparison['max_drawdown'] - float(comparison.loc['fmp', 'max_drawdown'])
print('Portfolio comparison:')
display(comparison.round(4))
# Out:
# /home/jlee153232/miniconda3/envs/quant-orchestrator/lib/python3.12/site-packages/backtesting/_plotting.py:50: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f3d598e1-2bfe-4495-82c9-785cbbe6fc54">Loading BokehJS ...</span>
#     </div>
# /home/jlee153232/PycharmProjects/quant-orchestrator/quant_orchestrator/backtests/research.py:476: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   symbol_summary = pd.concat(provider_rows, ignore_index=True)
# Symbol-level report:
#    provider symbol       start         end  bars  trades  final_equity  \
# 0       fmp   AAPL  2020-01-02  2026-06-24  1627       5      17226.20
# 1       fmp   AMZN  2020-01-02  2026-06-24  1627       5      13480.59
# 2       fmp  GOOGL  2020-01-02  2026-06-24  1627       3      27242.55
# 3       fmp   META  2020-01-02  2026-06-24  1627       3      21362.81
# 4       fmp   MSFT  2020-01-02  2026-06-24  1627       5      17108.09
# 5       fmp   NVDA  2020-01-02  2026-06-24  1627       2      77177.21
# 6       fmp   TSLA  2020-01-02  2026-06-24  1627       0      14285.71
# 7  yfinance   AAPL  2020-01-02  2026-06-23  1626       5      17346.35
# 8  yfinance   AMZN  2023-01-03  2026-06-23   870       3      14274.64
# 9  yfinance  GOOGL  2023-01-03  2026-06-23   870       2      20470.91
#
#    total_return  max_drawdown  elapsed_seconds
# 0        0.2058       -0.2110           0.0290
# 1       -0.0564       -0.2349           0.0260
# 2        0.9070       -0.1511           0.0274
# 3        0.4954       -0.1773           0.0263
# 4        0.1976       -0.1516           0.0264
# 5        4.4024       -0.2796           0.0267
# 6        0.0000        0.0000           0.0262
# 7        0.2142       -0.2036           0.0263
# 8       -0.0008       -0.2430           0.0183
# 9        0.4330       -0.1525           0.0186
# Portfolio report:
#    provider symbol  bars  trades  final_equity  total_return  max_drawdown  \
# 0       fmp   MAG7  1627      23     187883.19        0.8788       -0.1454
# 1  yfinance   MAG7  1626      21     131386.57        0.3139       -0.1687
#
#    elapsed_seconds
# 0           0.4716
# 1           0.1553
# Portfolio comparison:
#           total_return  max_drawdown  daily_vol  elapsed_seconds  \
# provider
# fmp             0.8788       -0.1454     0.0076           0.4716
# yfinance        0.3139       -0.1687     0.0057           0.1553
#
#           return_diff_vs_fmp  drawdown_diff_vs_fmp
# provider
# fmp                   0.0000                0.0000
# yfinance             -0.5649               -0.0233
